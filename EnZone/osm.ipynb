# %%
import folium
from zones import Marker, markers, circuts
from geopy import distance



omsk = Marker("omsk", "omsk", 54.991416, 73.364253)

m = folium.Map(location=[omsk.lat, omsk.long], zoom_start=11)



circ = folium.Circle(
    location=[circuts[1].lat, circuts[1].long], 
    radius=circuts[1].radius, 
    tooltip=circuts[1].name, 
    popup=circuts[1].name
    ).add_to(m)


for marker in markers:
    dist = distance.geodesic([circuts[1].lat, circuts[1].long], 
    [marker.lat, marker.long]).km * 1000
    if dist < circuts[1].radius:
        folium.Marker(location=[marker.lat, marker.long], 
        tooltip=marker.name, popup=marker.descriptions).add_to(m)

m
# Out:
# 2.855437990595713
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b328c9fd7235e67b81d33f28842db28a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b328c9fd7235e67b81d33f28842db28a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b328c9fd7235e67b81d33f28842db28a = L.map(
#                 &quot;map_b328c9fd7235e67b81d33f28842db28a&quot;,
#                 {
#                     center: [54.991416, 73.364253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9cfd6e1fef112ed5e1e453ffd4df11a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b328c9fd7235e67b81d33f28842db28a);
#
#
#             var circle_80f1cdad5451cf08c48ad65601b6d3b2 = L.circle(
#                 [54.967627, 73.347044],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b328c9fd7235e67b81d33f28842db28a);
#
#
#         var popup_4cd27269d7e03184ae19e8820b5471f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ff476da21d33baadb16f413ba90fd19 = $(`&lt;div id=&quot;html_9ff476da21d33baadb16f413ba90fd19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;zone_1&lt;/div&gt;`)[0];
#                 popup_4cd27269d7e03184ae19e8820b5471f5.setContent(html_9ff476da21d33baadb16f413ba90fd19);
#
#
#
#         circle_80f1cdad5451cf08c48ad65601b6d3b2.bindPopup(popup_4cd27269d7e03184ae19e8820b5471f5)
#         ;
#
#
#
#
#             circle_80f1cdad5451cf08c48ad65601b6d3b2.bindTooltip(
#                 `&lt;div&gt;
#                      zone_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_99cc9e63383fe054c8b780ee0ddef545 = L.marker(
#                 [54.988144, 73.360309],
#                 {}
#             ).addTo(map_b328c9fd7235e67b81d33f28842db28a);
#
#
#         var popup_8f04411a46a5873bc680cd825dca888a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b00d9ed752a9745785931604e86b6e07 = $(`&lt;div id=&quot;html_b00d9ed752a9745785931604e86b6e07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;dinamo&lt;/div&gt;`)[0];
#                 popup_8f04411a46a5873bc680cd825dca888a.setContent(html_b00d9ed752a9745785931604e86b6e07);
#
#
#
#         marker_99cc9e63383fe054c8b780ee0ddef545.bindPopup(popup_8f04411a46a5873bc680cd825dca888a)
#         ;
#
#
#
#
#             marker_99cc9e63383fe054c8b780ee0ddef545.bindTooltip(
#                 `&lt;div&gt;
#                      dinamo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f164fd1e4531f6c634e4e61aa5f18a7 = L.marker(
#                 [54.990163, 73.366649],
#                 {}
#             ).addTo(map_b328c9fd7235e67b81d33f28842db28a);
#
#
#         var popup_e3dafb5fcb56d28a6cf67e8408e6d876 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b0dee9fe721fbbc6c94c5ff4efcaad8 = $(`&lt;div id=&quot;html_8b0dee9fe721fbbc6c94c5ff4efcaad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;sobor&lt;/div&gt;`)[0];
#                 popup_e3dafb5fcb56d28a6cf67e8408e6d876.setContent(html_8b0dee9fe721fbbc6c94c5ff4efcaad8);
#
#
#
#         marker_2f164fd1e4531f6c634e4e61aa5f18a7.bindPopup(popup_e3dafb5fcb56d28a6cf67e8408e6d876)
#         ;
#
#
#
#
#             marker_2f164fd1e4531f6c634e4e61aa5f18a7.bindTooltip(
#                 `&lt;div&gt;
#                      sobor
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3afc053b1e01b66bbe8d5a5287a6509c = L.marker(
#                 [54.998086, 73.35887],
#                 {}
#             ).addTo(map_b328c9fd7235e67b81d33f28842db28a);
#
#
#         var popup_1ed7164c2d2f4bb76f89e0b3eb345f6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2352cc30b81628bf63c1387b0021adfc = $(`&lt;div id=&quot;html_2352cc30b81628bf63c1387b0021adfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;school_66&lt;/div&gt;`)[0];
#                 popup_1ed7164c2d2f4bb76f89e0b3eb345f6c.setConte
